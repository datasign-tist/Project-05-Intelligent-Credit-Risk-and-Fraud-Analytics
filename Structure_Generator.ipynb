# %%
import os

base_dir = "/Users/abhisheksharma/Documents/Data Science Projects/Project-05-Intelligent-Credit-Risk-&-Fraud-Analytics/"

folders  = ["data/raw","data/processed","src","src/data_generation","src/streaming","src/processing","src/modeling","src/rag","dags"]
files    = [".gitignore","requirements.txt","src/__init__.py","src/data_generation/__init__.py",
            "src/data_generation/generator.py","src/streaming/__init__.py","src/streaming/producer.py","src/processing/__init__.py","src/processing/stream_processor.py",
            "src/modeling/__init__.py","src/modeling/train_model.py","src/rag/__init__.py","src/rag/retriever.py",
            "main.py","run_producer.py","run_processor.py","run_training.py","run_rag.py",
            "data/raw/lending_policies.txt","DockerFile",".dockerignore",
            "dags/fraud_pipeline_dag.py"]

# Create base directory if not exists
os.makedirs(base_dir, exist_ok=True)

# Create folders safely
for folder in folders:
    folder_path = os.path.join(base_dir, folder)
    
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Created folder: {folder_path}")
    else:
        print(f"Folder already exists: {folder_path}")

# Create files safely (do not overwrite)
for file in files:
    file_path = os.path.join(base_dir, file)
    if not os.path.exists(file_path):
        with open(file_path, 'w') as f:
            pass
        print(f"Created file: {file_path}")
    else:
        print(f"File already exists: {file_path}")

print("Project structure setup complete!")
# Out:
# Folder already exists: /Users/abhisheksharma/Documents/Data Science Projects/Project-05-Intelligent-Credit-Risk-&-Fraud-Analytics/data/raw
# Folder already exists: /Users/abhisheksharma/Documents/Data Science Projects/Project-05-Intelligent-Credit-Risk-&-Fraud-Analytics/data/processed
# Folder already exists: /Users/abhisheksharma/Documents/Data Science Projects/Project-05-Intelligent-Credit-Risk-&-Fraud-Analytics/src
# Folder already exists: /Users/abhisheksharma/Documents/Data Science Projects/Project-05-Intelligent-Credit-Risk-&-Fraud-Analytics/src/data_generation
# Folder already exists: /Users/abhisheksharma/Documents/Data Science Projects/Project-05-Intelligent-Credit-Risk-&-Fraud-Analytics/src/streaming
# Folder already exists: /Users/abhisheksharma/Documents/Data Science Projects/Project-05-Intelligent-Credit-Risk-&-Fraud-Analytics/src/processing
# ...
